# %% [markdown]
# ### Data Manipulation and Analysis with Pandas
#
# Data manipulation and analysis are key tasks in any data science or data analysis project. Pandas provides a wide range of functions for data manipulation and analysis, making it easier to clean transform, and extract insights from data.

# %%
import pandas as pd

# %%
df=pd.read_csv('Details.csv')
## fetch the first 5 rows
df.head(5)
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681  1096.0     658         7  Electronics  Electronic Games
# 1  B-26055  5729.0      64        14    Furniture            Chairs
# 2  B-25955  2927.0     146         8    Furniture         Bookcases
# 3  B-26093  2847.0     712         8  Electronics          Printers
# 4  B-25602  2617.0    1151         4  Electronics            Phones
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card
# 4  Credit Card

# %%
df.tail(5)
# Out:
#      Order ID  Amount  Profit  Quantity     Category Sub-Category PaymentMode
# 1495  B-25700     7.0      -3         2     Clothing  Hankerchief         COD
# 1496  B-25757  3151.0     -35         7     Clothing     Trousers         EMI
# 1497  B-25973  4141.0    1698        13  Electronics     Printers         COD
# 1498  B-25698     7.0      -2         1     Clothing  Hankerchief         COD
# 1499  B-25993  4363.0     305         5    Furniture       Tables         EMI

# %%
df.describe()
# Out:
#             Amount      Profit     Quantity
# count  1498.000000  1500.00000  1500.000000
# mean    292.078772    24.64200     3.743333
# std     462.171306   168.55881     2.184942
# min       4.000000 -1981.00000     1.000000
# 25%      48.000000   -12.00000     2.000000
# 50%     122.000000     8.00000     3.000000
# 75%     326.750000    38.00000     5.000000
# max    5729.000000  1864.00000    14.000000

# %%
df.dtypes
# Out:
# Order ID         object
# Amount          float64
# Profit            int64
# Quantity          int64
# Category         object
# Sub-Category     object
# PaymentMode      object
# dtype: object

# %%
## Handling Missing Values
df.isnull().any()
# Out:
# Order ID        False
# Amount           True
# Profit          False
# Quantity        False
# Category        False
# Sub-Category    False
# PaymentMode     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Order ID        0
# Amount          2
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# dtype: int64

# %%
df_filled=df.fillna(0)

# %%
### Filling missing values with the mean of the column
df['Amount_fillNA']=df['Amount'].fillna(df['Amount'].mean())
df
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681  1096.0     658         7  Electronics  Electronic Games
# 1     B-26055  5729.0      64        14    Furniture            Chairs
# 2     B-25955  2927.0     146         8    Furniture         Bookcases
# 3     B-26093  2847.0     712         8  Electronics          Printers
# 4     B-25602  2617.0    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700     7.0      -3         2     Clothing       Hankerchief
# 1496  B-25757  3151.0     -35         7     Clothing          Trousers
# 1497  B-25973  4141.0    1698        13  Electronics          Printers
# 1498  B-25698     7.0      -2         1     Clothing       Hankerchief
# 1499  B-25993  4363.0     305         5    Furniture            Tables
#
#       PaymentMode  Amount_fillNA
# 0             COD         1096.0
# 1             EMI         5729.0
# 2             EMI         2927.0
# 3     Credit Card         2847.0
# 4     Credit Card         2617.0
# ...           ...            ...
# 1495          COD            7.0
# 1496          EMI         3151.0
# 1497          COD         4141.0
# 1498          COD            7.0
# 1499          EMI         4363.0
#
# [1500 rows x 8 columns]

# %%
df.dtypes
# Out:
# Order ID          object
# Amount           float64
# Profit             int64
# Quantity           int64
# Category          object
# Sub-Category      object
# PaymentMode       object
# Amount_fillNA    float64
# dtype: object

# %%
## Renaming Columns
df=df.rename(columns={'ID':'Sales ID'})
df.head(5)
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681  1096.0     658         7  Electronics  Electronic Games
# 1  B-26055  5729.0      64        14    Furniture            Chairs
# 2  B-25955  2927.0     146         8    Furniture         Bookcases
# 3  B-26093  2847.0     712         8  Electronics          Printers
# 4  B-25602  2617.0    1151         4  Electronics            Phones
#
#    PaymentMode  Amount_fillNA
# 0          COD         1096.0
# 1          EMI         5729.0
# 2          EMI         2927.0
# 3  Credit Card         2847.0
# 4  Credit Card         2617.0

# %%
## change datatypes
df['Profit_new']=df['Profit'].astype(float)
df.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681  1096.0     658         7  Electronics  Electronic Games
# 1  B-26055  5729.0      64        14    Furniture            Chairs
# 2  B-25955  2927.0     146         8    Furniture         Bookcases
# 3  B-26093  2847.0     712         8  Electronics          Printers
# 4  B-25602  2617.0    1151         4  Electronics            Phones
#
#    PaymentMode  Amount_fillNA  Profit_new
# 0          COD         1096.0       658.0
# 1          EMI         5729.0        64.0
# 2          EMI         2927.0       146.0
# 3  Credit Card         2847.0       712.0
# 4  Credit Card         2617.0      1151.0

# %%
df['New Profit']=df['Profit'].apply(lambda x:x*1.5)
df.head(5)
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681  1096.0     658         7  Electronics  Electronic Games
# 1  B-26055  5729.0      64        14    Furniture            Chairs
# 2  B-25955  2927.0     146         8    Furniture         Bookcases
# 3  B-26093  2847.0     712         8  Electronics          Printers
# 4  B-25602  2617.0    1151         4  Electronics            Phones
#
#    PaymentMode  Amount_fillNA  Profit_new  New Profit
# 0          COD         1096.0       658.0       987.0
# 1          EMI         5729.0        64.0        96.0
# 2          EMI         2927.0       146.0       219.0
# 3  Credit Card         2847.0       712.0      1068.0
# 4  Credit Card         2617.0      1151.0      1726.5

# %%
## Data Aggregating and Grouping
grouped_mean=df.groupby('Order ID')['Profit'].mean()
print(grouped_mean)
# Out:
# Order ID
# B-25601    269.500000
# B-25602    195.000000
# B-25603    -22.500000
# B-25604     11.000000
# B-25605      0.000000
#               ...
# B-26096     20.166667
# B-26097    -77.142857
# B-26098     42.333333
# B-26099    214.750000
# B-26100     85.333333
# Name: Profit, Length: 500, dtype: float64

# %%
grouped_sum=df.groupby(['Order ID','Sub-Category'])['Amount'].sum()
print(grouped_sum)
# Out:
# Order ID  Sub-Category
# B-25601   Bookcases           1275.0
#           Electronic Games      80.0
#           Hankerchief            8.0
#           Stole                 66.0
# B-25602   Phones              3209.0
#                                ...
# B-26099   Skirt                  9.0
#           Trousers            2366.0
# B-26100   Chairs               828.0
#           Shirt                 72.0
#           T-shirt               34.0
# Name: Amount, Length: 1263, dtype: float64

# %%
## aggregate multiple functions
grouped_agg=df.groupby('Category')['Profit'].agg(['mean','sum','count'])
grouped_agg
# Out:
#                   mean    sum  count
# Category
# Clothing     14.041096  13325    949
# Electronics  42.733766  13162    308
# Furniture    43.111111  10476    243

# %%
### Merging and joining Dataframes
df1=pd.read_csv('Details.csv')
df2=pd.read_csv('Orders.csv')

# %%
df1.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681  1096.0     658         7  Electronics  Electronic Games
# 1  B-26055  5729.0      64        14    Furniture            Chairs
# 2  B-25955  2927.0     146         8    Furniture         Bookcases
# 3  B-26093  2847.0     712         8  Electronics          Printers
# 4  B-25602  2617.0    1151         4  Electronics            Phones
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card
# 4  Credit Card

# %%
df2.head()
# Out:
#   Order ID  Order Date CustomerName           State     City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi    Delhi
# 2  B-25973  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 3  B-25923  27-12-2018        Gopal     Maharashtra   Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh   Indore

# %%
## Merge Dataframes on the Order ID columns
pd.merge(df1,df2,on="Order ID",how="inner")
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681  1096.0     658         7  Electronics  Electronic Games
# 1     B-26055  5729.0      64        14    Furniture            Chairs
# 2     B-25955  2927.0     146         8    Furniture         Bookcases
# 3     B-26093  2847.0     712         8  Electronics          Printers
# 4     B-25602  2617.0    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700     7.0      -3         2     Clothing       Hankerchief
# 1496  B-25757  3151.0     -35         7     Clothing          Trousers
# 1497  B-25973  4141.0    1698        13  Electronics          Printers
# 1498  B-25698     7.0      -2         1     Clothing       Hankerchief
# 1499  B-25993  4363.0     305         5    Furniture            Tables
#
#       PaymentMode  Order Date CustomerName           State     City
# 0             COD  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 1             EMI  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 2             EMI  16-01-2018        Shiva     Maharashtra     Pune
# 3     Credit Card  27-03-2018       Sarita     Maharashtra     Pune
# 4     Credit Card  01-04-2018       Vrinda     Maharashtra     Pune
# ...           ...         ...          ...             ...      ...
# 1495          COD  25-06-2018       Shubhi     Maharashtra   Mumbai
# 1496          EMI  21-08-2018     Vishakha  Madhya Pradesh   Indore
# 1497          COD  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 1498          COD  23-06-2018       Amisha      Tamil Nadu  Chennai
# 1499          EMI  03-02-2018       Madhav           Delhi    Delhi
#
# [1500 rows x 11 columns]

# %%
pd.merge(df1,df2,on="Order ID",how="outer")
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25601    80.0     -56         4  Electronics  Electronic Games
# 1     B-25601    66.0     -12         5     Clothing             Stole
# 2     B-25601  1275.0    1148         7    Furniture         Bookcases
# 3     B-25601     8.0      -2         3     Clothing       Hankerchief
# 4     B-25602  2617.0    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099  2366.0     552         5     Clothing          Trousers
# 1496  B-26099     9.0       3         1     Clothing             Skirt
# 1497  B-26100   828.0     230         2    Furniture            Chairs
# 1498  B-26100    34.0      10         2     Clothing           T-shirt
# 1499  B-26100    72.0      16         2     Clothing             Shirt
#
#       PaymentMode  Order Date CustomerName           State       City
# 0             UPI  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1             UPI  01-04-2018       Bharat         Gujarat  Ahmedabad
# 2             EMI  01-04-2018       Bharat         Gujarat  Ahmedabad
# 3     Credit Card  01-04-2018       Bharat         Gujarat  Ahmedabad
# 4     Credit Card  01-04-2018       Vrinda     Maharashtra       Pune
# ...           ...         ...          ...             ...        ...
# 1495          UPI  30-03-2018       Bhishm     Maharashtra     Mumbai
# 1496          COD  30-03-2018       Bhishm     Maharashtra     Mumbai
# 1497          COD  31-03-2018       Hitika  Madhya Pradesh     Indore
# 1498   Debit Card  31-03-2018       Hitika  Madhya Pradesh     Indore
# 1499          COD  31-03-2018       Hitika  Madhya Pradesh     Indore
#
# [1500 rows x 11 columns]

# %%
pd.merge(df1,df2,on="Order ID",how="left")
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681  1096.0     658         7  Electronics  Electronic Games
# 1     B-26055  5729.0      64        14    Furniture            Chairs
# 2     B-25955  2927.0     146         8    Furniture         Bookcases
# 3     B-26093  2847.0     712         8  Electronics          Printers
# 4     B-25602  2617.0    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700     7.0      -3         2     Clothing       Hankerchief
# 1496  B-25757  3151.0     -35         7     Clothing          Trousers
# 1497  B-25973  4141.0    1698        13  Electronics          Printers
# 1498  B-25698     7.0      -2         1     Clothing       Hankerchief
# 1499  B-25993  4363.0     305         5    Furniture            Tables
#
#       PaymentMode  Order Date CustomerName           State     City
# 0             COD  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 1             EMI  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 2             EMI  16-01-2018        Shiva     Maharashtra     Pune
# 3     Credit Card  27-03-2018       Sarita     Maharashtra     Pune
# 4     Credit Card  01-04-2018       Vrinda     Maharashtra     Pune
# ...           ...         ...          ...             ...      ...
# 1495          COD  25-06-2018       Shubhi     Maharashtra   Mumbai
# 1496          EMI  21-08-2018     Vishakha  Madhya Pradesh   Indore
# 1497          COD  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 1498          COD  23-06-2018       Amisha      Tamil Nadu  Chennai
# 1499          EMI  03-02-2018       Madhav           Delhi    Delhi
#
# [1500 rows x 11 columns]

# %%
pd.merge(df1,df2,on="Order ID",how="right")
# Out:
#      Order ID  Amount  Profit  Quantity     Category Sub-Category  \
# 0     B-26055  5729.0      64        14    Furniture       Chairs
# 1     B-26055   671.0     114         9  Electronics       Phones
# 2     B-26055   443.0      11         1     Clothing        Saree
# 3     B-26055    57.0       7         2     Clothing        Shirt
# 4     B-26055   227.0      48         5     Clothing        Stole
# ...       ...     ...     ...       ...          ...          ...
# 1495  B-25742    11.0      -8         2     Clothing        Skirt
# 1496  B-26088    11.0       5         2     Clothing  Hankerchief
# 1497  B-25707     8.0      -6         1     Clothing        Stole
# 1498  B-25758     8.0      -2         1     Clothing        Stole
# 1499  B-26095     6.0       1         1     Clothing        Kurti
#
#       PaymentMode  Order Date CustomerName             State     City
# 0             EMI  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 1     Credit Card  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 2             COD  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 3             UPI  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# 4             COD  10-03-2018    Harivansh     Uttar Pradesh  Mathura
# ...           ...         ...          ...               ...      ...
# 1495          UPI  03-08-2018       Ashwin               Goa      Goa
# 1496          UPI  26-03-2018       Bhavna            Sikkim  Gangtok
# 1497          COD  01-07-2018      Shivani       Maharashtra   Mumbai
# 1498          COD  22-08-2018      Shubham  Himachal Pradesh    Simla
# 1499          UPI  28-03-2018      Monisha         Rajasthan   Jaipur
#
# [1500 rows x 11 columns]
